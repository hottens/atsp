# %%
from os import listdir
from os.path import isfile, join

apk_path = 'APKs'

apks = [f for f in listdir(apk_path) if isfile(join(apk_path, f))]

apks
# Out:
# ['a.a.hikidashi.apk',
#  'a.akakao.bong_ment.apk',
#  'a.b.wassim.guide.apk',
#  'a.duMobile.srv.apk',
#  'a2works.com.br.battery.apk',
#  'a2works.com.br.ipva_ba.apk',
#  'a2works.com.br.ipva_pr.apk',
#  'a2z.Mobile.Event3478.apk',
#  'a2z.Mobile.Event3649.apk',
#  'a2z.Mobile.Event4086.apk',
#  'a2z.Mobile.Event4208.apk',
#  'aave.lifebarometer.apk',
#  'ab.gamming.meteoriteWash.apk',
#  'ab4tec.com.chronometerandtimer.apk',
#  'abcom.com.timeconverter.apk',
#  'abcom.istom.lovelywallpaper.apk',
#  'abd.abdallah.igli5.apk',
#  'abd.abdallah.islam.youtube.apk',
#  'abd.abdallah.uptodate.youtube.apk',
#  'abhishek.arcdroid.tenth.apk',
#  'aboutdharma.com.apk',
#  'abstractionvideolwp.led.com.apk',
#  'ac.omonoia.nic.apk',
#  'ac.rj.staff.apk',
#  'ac.robinson.chameleonnotifier.apk',
#  'ac.robinson.mediaphone.apk',
#  'ac.robinson.mediatablet.apk',
#  'acne.blogtreat.apk',
#  'acquadinepi.erioni.al.apk',
#  'acs.borntf.ncs.apk',
#  'acs.tools.matheass.apk',
#  'acs.tools.preisvergleich.apk',
#  'act.activity.apk',
#  'action.aspirvictorymanagement.flappy.dragon.dash.jungle.apk',
#  'adampinsky.com.stormy.apk',
#  'addis.keyboard.apk',
#  'adikar.com.photogifmaker.apk',
#  'adone.daily.call.apk',
#  'adrianoferraguto.oraesatta.apk',
#  'adroid.driverlad.apk',
#  'ads.storestory.be.blackdragon.apk',
#  'adsindy.com.terla.apk',
#  'adsprotech.games.ball.shooter.two.apk',
#  'adtech.chitchat.apk',
#  'adult.coloring.book.zendalas.apk',
#  'adyourself.shakeyourfoto.apk',
#  'adyourself.tomorrow_smog.apk',
#  'ae.brandsforless.android.apk',
#  'ae.gov.ambulance.myarabic2.apk',
#  'ae.gov.dubaicustoms.mobile.apk',
#  'aerostone.bigear.apk',
#  'aesthetic.developers.flyingbirdy.apk',
#  'afd.app.ansaar.afd.apk',
#  'afk.passpal.free.apk',
#  'afkari.io.kalimathobei.apk',
#  'afzkl.development.ShoppingList.apk',
#  'ageagebatsugame.taro.apk',
#  'agency.contra.apps.kpmg.kpmgglobalevent.apk',
#  'agexdev.theroad.apk',
#  'agurapps.games.amazingmemory.apk',
#  'agurapps.games.BallAndPaddles.apk',
#  'ah.woeid.apk',
#  'ahmad.appiques.mtdm.apk',
#  'ahmed.restau.apk',
#  'aidapp.newsportalhimachalpradesh.apk',
#  'aidapp.newsportalodisha.apk',
#  'aidapp.newsportaltamilnadu.apk',
#  'aidc.mx.efireport.apk',
#  'air.A20rarepepes.apk',
#  'air.A3bibe.apk',
#  'air.A40haditsakhirzaman.apk',
#  'air.A43XLIII.apk',
#  'air.agara.games.ChessmasterFree.apk',
#  'air.air.Bread.apk',
#  'air.air.FlashPunk.apk',
#  'air.air.flexshapes.apk',
#  'air.air.HTML5MobileApp.apk',
#  'air.air.it.aquacode.memory.AquaMemory.apk',
#  'air.air.lido.LidoMobile.apk',
#  'air.air.lyl.ThreeKingdomsFT.apk',
#  'air.air.monsterbraingames.cutit.apk',
#  'air.air.Sokoban3D.apk',
#  'air.AIRMapViewer.apk',
#  'air.Airshooting.apk',
#  'air.ajazgames.ajaztreasurehunt2.apk',
#  'air.ajazgames.babysnailescape.apk',
#  'air.ajazgames.colorsquareescape.apk',
#  'air.AJAZGAMES.escapeabandonedgreyshades.apk',
#  'air.ajazgames.escapegamesultan.apk',
#  'air.ajazgames.escapekindnessthanksgiving.apk',
#  'air.ajazgames.escapepickypicnic.apk',
#  'air.ajazgames.escapepixiedivine.apk',
#  'air.ajazgames.escapesnapperfish.apk',
#  'air.ajazgames.motorescape.apk',
#  'air.ajazgames.pumpkinboyhalloweenescape.apk',
#  'air.ajazgames.santaiceescape.apk',
#  'air.ajazgames.skimpyescape.apk',
#  'air.ajazzgames.escapeallhallowseve.apk',
#  'air.AngryNuts.apk',
#  'air.animations.apk',
#  'air.app.mmstudio.mmvisual.todysbabybook.apk',
#  'air.apps.NewsEnterprise.canadanewspapers.apk',
#  'air.apps.NewsEnterprise.deutschezeitungen.apk',
#  'air.apps.NewsEnterprise.gazeteler.apk',
#  'air.apps.NewsEnterprise.indianewspapers.apk',
#  'air.apps.NewsEnterprise.lesjournauxenfrancais.apk',
#  'air.apps.NewsEnterprise.mediatakeout.apk',
#  'air.apps.NewsEnterprise.surinamenieuws.apk',
#  'air.apps.NewsEnterprise.voetbalnieuws.apk',
#  'air.ArabicLetterBox.apk',
#  'air.Archerfree.apk',
#  'air.Astro.apk',
#  'air.atasaati.apk',
#  'air.AThanksgivingToRemember.apk',
#  'air.Autism.Things.apk',
#  'air.AvmGames.MapleHouseEscape.apk',
#  'air.BabyBearSurgerySimulator.apk',
#  'air.BabyCleaningDay2.apk',
#  'air.babyemmachristmasdressup.apk',
#  'air.babyshapes.apk',
#  'air.BadjaoGirl.apk',
#  'air.BasketballHustleForCel.apk',
#  'air.BeautyTipsinTamil.apk',
#  'air.BestEscape82WaterPool.apk',
#  'air.bg.teracomm.vivablitz.apk',
#  'air.BJC.apk',
#  'air.BlackjackCity.apk',
#  'air.BodyAtlas.apk',
#  'air.br.com.buracojustificadomano.mobile.apk',
#  'air.br.com.cc2002.tablet.free.A2013.apk',
#  'air.br.com.ciss.mobile.vendas.android.apk',
#  'air.br.com.epagri.ciram.apk',
#  'air.br.com.helme.bitbitrobotandroid.apk',
#  'air.br.com.iasoft.cc2002.tablet.A2014.apk',
#  'air.br.com.netpoint.aasp.apk',
#  'air.br.com.netpoint.apptvunilever.apk',
#  'air.br.com.netpoint.conacabac.apk',
#  'air.br.com.netpoint.gdp.apk',
#  'air.br.com.netpoint.gvc.apk',
#  'air.br.com.netpoint.integraeventos.apk',
#  'air.br.com.netpoint.integragestao.apk',
#  'air.br.com.netpoint.integravconf.apk',
#  'air.br.com.netpoint.remateweb.apk',
#  'air.br.com.netpoint.vconf.apk',
#  'air.br.com.pifpaf.mobile.apk',
#  'air.br.ingrupochp.boletimEmpreendedor.apk',
#  'air.brightest.chinatractorracing2.apk',
#  'air.brightest.stuntratunderground.apk',
#  'air.brightest.yetiextrememotocross.apk',
#  'air.bullstudios.mermaiddoctor.apk',
#  'air.bullstudios.princessdoctorr.apk',
#  'air.burninfree.apk',
#  'air.busythings.androidapps.animalmuddle.apk',
#  'air.Bus_Stop_Parking.apk',
#  'air.ca.ax2.holidaySnapshot.apk',
#  'air.Candybarcupcakes.apk',
#  'air.carlene.ZombieVirus.apk',
#  'air.CarLoanCalculation.apk',
#  'air.CarolAndroid.apk',
#  'air.cellphoneescape.apk',
#  'air.ChaletGrandCerfEscape.apk',
#  'air.charmudex.apk',
#  'air.CheerfulGirlMatching.apk',
#  'air.Chemical_Place_Escape.apk',
#  'air.ChiralCube.apk',
#  'air.Christmascoloringbook3.apk',
#  'air.ChristmasPuddingCakePops.apk',
#  'air.cindycakemakerlite.apk',
#  'air.co.yapps.ezan.apk',
#  'air.com.abecedaire.JapaneseBrush.apk',
#  'air.com.absolutist.match3puzzle.bubblezbubbledefence.apk',
#  'air.com.aetrex.aetrexretailapp.apk',
#  'air.com.alchemiagames.offside.apk',
#  'air.com.alibabacave.CMemory2.apk',
#  'air.com.amazingzhus.amazingzhus.apk',
#  'air.com.ami.agada.apk',
#  'air.com.amihanya.Pray.apk',
#  'air.com.aminocookinchklo.selasaharablila.apk',
#  'air.com.animatedsoftware.PavlovsDog.apk',
#  'air.com.applaudsolutions.emp.EmployeeCenterMobile.apk',
#  'air.com.applauz.brickpic.apk',
#  'air.com.applauz.drizzyviews.apk',
#  'air.com.applauz.legominifigures.apk',
#  'air.com.applauz.wutangme.apk',
#  'air.com.apptaught.MEDpro.apk',
#  'air.com.apptaught.realestateTrial.apk',
#  'air.com.aquariumdeathstickman.apk']

# %%
from androguard.misc import AnalyzeAPK
from os import listdir
from os.path import isfile, join

apk_path = 'APKs'

apks = [f for f in listdir(apk_path) if isfile(join(apk_path, f))]

for apk in apks:
    a, d, dx = AnalyzeAPK(join(apk_path, apk))
    if not 'Landroid/webkit/WebSettings;' in dx.classes: continue
    for meth in dx.classes['Landroid/webkit/WebSettings;'].get_methods():
        if meth.name == 'setUserAgentString':
            print(apk)
            continue
# Out:
# a.a.hikidashi.apk
# a.b.wassim.guide.apk
# a2works.com.br.battery.apk
# a2works.com.br.ipva_ba.apk
# a2works.com.br.ipva_pr.apk
# aave.lifebarometer.apk
# ab4tec.com.chronometerandtimer.apk
# abcom.com.timeconverter.apk
# abcom.istom.lovelywallpaper.apk
# abd.abdallah.igli5.apk
# abd.abdallah.islam.youtube.apk
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-8a1d88cb666c> in <module>
#       8
#       9 for apk in apks:
# ---> 10     a, d, dx = AnalyzeAPK(join(apk_path, apk))
#      11     #for c in dx.get_classes():
#      12     if not 'Landroid/webkit/WebSettings;' in dx.classes: continue
#
# c:\users\hayoo\appdata\local\programs\python\python37-32\lib\site-packages\androguard\misc.py in AnalyzeAPK(_file, session, raw)
#      65         dx = Analysis()
#      66         for dex in a.get_all_dex():
# ---> 67             df = DalvikVMFormat(dex, using_api=a.get_target_sdk_version())
#      68             dx.add(df)
#      69             d.append(df)
#
# c:\users\hayoo\appdata\local\programs\python\python37-32\lib\site-packages\androguard\core\bytecodes\dvm.py in __init__(self, buff, decompiler, config, using_api)
#    7558
#    7559         self._preload(buff)
# -> 7560         self._load(buff)
#    7561
#    7562     def _preload(self, buff):
#
# c:\users\hayoo\appdata\local\programs\python\python37-32\lib\site-packages\androguard\core\bytecodes\dvm.py in _load(self, buff)
#    7570             log.warning("no map list! This DEX file is probably empty.")
#    7571         else:
# -> 7572             self.map_list = MapList(self.CM, self.header.map_off, self)
#    7573
#    7574             self.classes = self.map_list.get_item_type(TypeMapItem.CLASS_DEF_ITEM)
#
# c:\users\hayoo\appdata\local\programs\python\python37-32\lib\site-packages\androguard\core\bytecodes\dvm.py in __init__(self, cm, off, buff)
#    7453                 c_item = mi.get_item()
#    7454
# -> 7455             self.CM.add_type_item(mi.get_type(), mi, c_item)
#    7456
#    7457     def get_off(self):
#
# c:\users\hayoo\appdata\local\programs\python\python37-32\lib\site-packages\androguard\core\bytecodes\dvm.py in add_type_item(self, type_item, c_item, item)
#    7166                 self.__manage_item_off.append(goff)
#    7167
# -> 7168                 self.__obj_offset[i.get_off()] = i
#    7169
#    7170                 if type_item == TypeMapItem.STRING_DATA_ITEM:
#
# MemoryError:
